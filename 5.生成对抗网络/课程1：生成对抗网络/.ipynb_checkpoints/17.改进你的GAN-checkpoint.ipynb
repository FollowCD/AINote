# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
#
# ## 注释
#
# https://arxiv.org/pdf/1606.03498.pdf
#
#  Improved Techniques for Training GANs：https://arxiv.org/pdf/1606.03498.pdf
#
#   批次归一化（Batch Normalization）：https://arxiv.org/abs/1502.03167
