# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 链接
#  [UCI 机器学习数据库](https://archive.ics.uci.edu/ml/datasets/Bike+Sharing+Dataset)
#
# [ GitHub 代码库](https://github.com/udacity/cn-deep-learning)
#
# [很棒的来自 Frank Chen 的视频](https://s3.cn-north-1.amazonaws.com.cn/static-documents/nd101/AI%2C+Deep+Learning%2C+and+Machine+Learning_+A+Primer.mp4)
