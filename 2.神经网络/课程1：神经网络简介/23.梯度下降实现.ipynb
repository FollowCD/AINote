# %% [markdown]
# ## 梯度下降
# 在这节课，我们将学习梯度下降算法背后的准则和数学原理。
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
