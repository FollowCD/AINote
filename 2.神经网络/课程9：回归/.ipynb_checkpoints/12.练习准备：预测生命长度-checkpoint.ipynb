# %% [markdown]
# ## 用线性回归预测预期寿命
# 在该实验室中，你将使用关于出生时的平均预期寿命以及全世界男性的平均BMI的数据。 数据来自[Gapminder](https://www.gapminder.org/)。
#
# ## 工作区
# Notebook 将在课堂内打开。 但是，如果您想单独打开它，可以从 [GitHub仓库](https://github.com/udacity/deep-learning/tree/master/linear-regression) 中克隆这些资料。
# ![image.png](attachment:image.png)
