# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
#
# ## 注释
# 研究表明：http://www.cs.toronto.edu/~fritz/absps/imagenet.pdf
#
#  Andrej Karpathy 的 CS231n 课程：http://cs231n.github.io/neural-networks-1/#nn
#
#  softmax：https://en.wikipedia.org/wiki/Softmax_function
#
#  分类手写数字：http://yann.lecun.com/exdb/mnist/
#
#  MNIST数据集：http://yann.lecun.com/exdb/mnist/
