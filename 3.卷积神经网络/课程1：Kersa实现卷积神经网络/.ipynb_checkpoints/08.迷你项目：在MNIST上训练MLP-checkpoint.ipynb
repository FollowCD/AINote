# %% [markdown]
# ## 迷你项目：在 MNIST 上 训练 MLP
# 对于深度学习 [尚未充分理解](https://www.technologyreview.com/s/604087/the-dark-secret-at-the-heart-of-ai/) 时，在很多情况下，实践先于理论。如果你刚接触深度学习，强烈建议并鼓励你利用各种模型进行试验，了解模型工作原理。Github 提供了 [初学者代码](https://github.com/udacity/aind2-cnn)。
#
# 在这个迷你项目中，你将在 [mnist_mlp.ipynb](https://github.com/udacity/aind2-cnn/blob/master/mnist-mlp/mnist_mlp.ipynb) 中，修改神经网络，比较结果模型配置。
#
# **记住**：通过对比验证损失和训练损失，发现过度拟合。如果训练损失远远低于验证损失，那么这个模型可能过度拟合。
# ![image.png](attachment:image.png)
# ## 可选资源
# 如果你想在神经网络中更加系统地检索超参数，请查阅这篇 [博文](http://machinelearningmastery.com/grid-search-hyperparameters-deep-learning-models-python-keras/)。
