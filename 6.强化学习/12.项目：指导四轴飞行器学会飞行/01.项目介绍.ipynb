# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
#
# ## 注释
# GitHub:https://github.com/udacity/cn-deep-learning/tree/master/RL-Quadcopter-2
#
# 审阅标准：https://review.udacity.com/#!/rubrics/1589/view
