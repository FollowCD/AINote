# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
#     """
#     这是 Gridworld Cliff 强化学习任务的简单实现。
#     改编自《强化学习：简介》（作者：Sutton 和 Barto）的示例 6.6（第 145 页）
#     http://people.inf.elte.hu/lorincz/Files/RL_2006/SuttonBook.pdf
#
#     灵感来自：
#     https://github.com/dennybritz/reinforcement-learning/blob/master/lib/envs/cliff_walking.py
#     该板是一个 4x12 的矩阵（使用 Numpy 矩阵索引）：
#         左下角的 [3, 0] 是起点
#         右下角的 [3, 11] 是目标
#         底部中心的 [3, 1..10] 是悬崖
#     每个时间步都会获得 -1 奖励，跌入悬崖会获得 -100 奖励并重置为起点。当智能体抵达目标时阶段结束。
#     """
# ## 注释
#
# 教科书：http://go.udacity.com/rl-textbook
#
# GitHub文件：https://github.com/openai/gym/blob/master/gym/envs/toy_text/cliffwalking.py
#
# 此链接：http://go.udacity.com/rl-textbook
