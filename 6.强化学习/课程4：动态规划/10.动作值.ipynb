# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 注释
#
# (条件性)概率分布：https://en.wikipedia.org/wiki/Conditional_probability_distribution
#
# 期望值：https://en.wikipedia.org/wiki/Expected_value
