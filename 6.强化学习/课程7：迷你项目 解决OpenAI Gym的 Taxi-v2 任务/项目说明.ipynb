# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
#
# ## 注释
#
# 解决：https://gym.openai.com/envs/Taxi-v1/
#
#  OpenAI Gym Leaderboard：https://github.com/openai/gym/wiki/Leaderboard
