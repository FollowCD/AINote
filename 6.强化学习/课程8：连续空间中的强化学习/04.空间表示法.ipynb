# %% [markdown]
# ![image.png](attachment:image.png)
#
# 答案：
#
# 请参阅此[环境表格](https://github.com/openai/gym/wiki/Table-of-environments)，了解 OpenAI Gym 中提供的环境。这里，Discrete(...) 表示离散空间，Box(...) 表示连续空间。更多详情请参阅此[文档](https://gym.openai.com/docs/#spaces)。
