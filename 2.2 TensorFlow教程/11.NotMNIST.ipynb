# %% [markdown]
# ![image.png](attachment:image.png)
# ```
# git clone https://github.com/udacity/deep-learning.git
# ```

# %% [markdown]
# 如果你对 Git 和 GitHub 不熟悉，我强烈建议你查看[我们的课程](https://cn.udacity.com/course/how-to-use-git-and-github--ud775)。 如果你不想使用 Git，则可以将该仓库以Zip文件形式下载下来。 你可以在这里找到这个[仓库](https://github.com/udacity/deep-learning)。

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 这是一个自我评估的实验室。你可以将你的答案和解决方案在[这里](https://github.com/udacity/deep-learning/blob/master/intro-to-tensorflow/intro_to_tensorflow_solution.ipynb)进行比较。如果你在完成实验时遇到任何困难，优达学城 会提供一些服务来回答你可能遇到的任何问题。
#
# ## 帮助指南
# 请记住，你可以从导师，论坛（单击教室左侧的链接）或 Slack 频道获得学习帮助。你还可以查看以前课程中的页面来回顾学习到的知识。
