# %% [markdown]
# ## Skip-gram 练习
# 下面我介绍下 notebook 。你可以在我们的 [GitHub 资源库](https://github.com/udacity/deep-learning/tree/master/embeddings)中找到该 notebook。你可以下载下来，或将其克隆到你的计算机上。
#
# 要求：你需要 Numpy、Matplotlib、Scikit-learn、tqdm 和 TensorFlow 1.0 才能运行此代码。
#
# 下面是完整的介绍视频。然后，我将提供视频每个部分的时间戳链接。
# ![image.png](attachment:image.png)
