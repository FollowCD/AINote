# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 接下来的几个视频将关注反向传播过程，即使用链式法则的随机梯度下降。
#
# ## 注释
#
# 线性组合：http://linear.ups.edu/html/section-LC.html
#
# 矩阵乘法：https://en.wikipedia.org/wiki/Matrix_multiplication
#
# 激活函数此处：https://github.com/Kulbear/deep-learning-nano-foundation/wiki/ReLU-and-Softmax-Activation-Functions
#
# 均方误差(MSE)：https://en.wikipedia.org/wiki/Mean_squared_error
#
# 交叉熵：https://www.ics.uci.edu/~pjsadows/notes.pdf
