# %% [markdown]
# ![image.png](attachment:image.png)
#
# ## 注释
#
# 梯度消失：https://en.wikipedia.org/wiki/Vanishing_gradient_problem
#
# 等比数列：https://socratic.org/algebra/exponents-and-exponential-functions/geometric-sequences-and-exponential-functions
#
# 时延神经网络：https://en.wikipedia.org/wiki/Time_delay_neural_network
#
# Elman网络：http://onlinelibrary.wiley.com/doi/10.1207/s15516709cog1402_1/abstract
#
# 额外信息：https://en.wikipedia.org/wiki/Recurrent_neural_network#Elman_networks_and_Jordan_networks
#
# LSTM：http://www.bioinf.jku.at/publications/older/2604.pdf
#
# Sepp Hochreiter：https://en.wikipedia.org/wiki/Sepp_Hochreiter
#
# Jürgen Schmidhuber：http://people.idsia.ch/~juergen/
#
# 博客：https://deeplearning4j.org/cn/lstm
