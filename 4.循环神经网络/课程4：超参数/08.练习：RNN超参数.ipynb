# %% [markdown]
# 提示：GRU 在特定任务中的训练速度更快，而 LSTM 较为常用。
#
# 此外，在深度学习中很少有明确的答案。很多问题的最佳答案通常是“取决于实际情况”。
#
# ![image.png](attachment:image.png)

# %% [markdown]
# 提示：也许在未来的某个时候，或者对于非常具体的任务，极大的嵌入大小更好。但是绝大多数情况下，较小的嵌入大小便可以了。
# ![image.png](attachment:image.png)
