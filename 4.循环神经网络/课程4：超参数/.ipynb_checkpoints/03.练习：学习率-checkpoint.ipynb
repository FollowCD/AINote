# %% [markdown]
# ![image.png](attachment:image.png)
# 提示：1- 模型在进行训练吗？误差是否降低了？ 2- 如果模型在进行训练，它是否在某两个值之间振荡（可能说明学习率太大）？或者它是否在以非常小的步长降低误差（可能说明学习率太小）？
#
# 答案：模型在进行训练，但速度太慢。提高学习率将使优化器以更大的步长将参数推向最佳值。

# %% [markdown]
# ![image.png](attachment:image.png)
#
# 提示：训练误差振荡可能表明，训练过程在达到最佳值之前，遭遇了误差曲线的瓶颈。这可能是由于学习率过大而引起。
#
# 这个问题可能有多个解决方案。
